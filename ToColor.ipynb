# %%
from Tracker import *

# %%
CELL_SELECTION = 0
path = "New_Visualization_Step/AI_Segmentation_Output/seg_t2/txt_outlines/11_cp_outlines.txt"

# %%
cells = load_outlines(path)
centers = get_centers(cells)
centers_dict = centers_to_dict(centers)

# %%
from ColorGenerator import *

# %%
colors = generate_unique_colors(centers)

# %%
import matplotlib.pyplot as plt

# Create a figure and axis
fig, ax = plt.subplots()

# Plot each coordinate with its respective color
for color, coords in colors.items():
    ax.scatter(coords[0], coords[1], color=[c/255 for c in color], label=str(color))

# Set labels and title
ax.set_xlabel('X Coordinate')
ax.set_ylabel('Y Coordinate')
ax.set_title('Coordinates with Colors')

# Show the plot
plt.show()
