# %% [markdown]
# <a href="https://colab.research.google.com/github/MouseLand/cellpose/blob/main/notebooks/run_cellpose_2.0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Running cellpose 2.0 in colab with a GPU
#
# <font size = 4>Cellpose 2.0 now allows you to train your own models in the GUI!
#
# This notebook allows you to load this **custom model** and run the model on your images with a GPU.
#
# In this notebook, you can also **train** a custom model using your labels (`_seg.npy`) files, or other labels as `_masks.tif` files. If you already have a trained model, skip this part of the notebook.
#
# For more details on cellpose 2.0 check out the [paper](https://www.biorxiv.org/content/10.1101/2022.04.01.486764v1) or the [talk](https://www.youtube.com/watch?v=3ydtAhfq6H0).
#
# Mount your google drive to access all your image files, segmentations, and custom models. This also ensures that any models you train are saved to your google drive. If you'd like to try out the notebook without your own files, please download the sample images from tissuenet (optional step in Setup below).
#
# This notebook was inspired by the Zero-Cost Deep-Learning to Enhance Microscopy project (https://github.com/HenriquesLab/DeepLearning_Collab/wiki). Jointly developed by the Jacquemet (link to https://cellmig.org/) and Henriques (https://henriqueslab.github.io/) laboratories. Please check out their great work!

# %% [markdown]
# # Setup
#
# We will first install cellpose 2.0, check the GPU is working, and mount google drive to get your models and images.

# %% [markdown]
# ## Installation

# %% [markdown]
# Install cellpose -- by default the torch GPU version is installed in COLAB notebook.

# %%
# %pip install "opencv-python-headless<4.3"
# %pip install cellpose
# Out:
# Requirement already satisfied: opencv-python-headless<4.3 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (3.4.18.65)
# Requirement already satisfied: numpy>=1.21.2 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from opencv-python-headless<4.3) (1.26.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: cellpose in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (3.0.7)
# Requirement already satisfied: numpy>=1.20.0 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (1.26.3)
# Requirement already satisfied: scipy in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (1.11.4)
# Requirement already satisfied: natsort in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (8.4.0)
# Requirement already satisfied: tifffile in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (2024.1.30)
# Requirement already satisfied: tqdm in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (4.65.0)
# Requirement already satisfied: numba>=0.53.0 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (0.59.0)
# Requirement already satisfied: llvmlite in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (0.42.0)
# Requirement already satisfied: torch>=1.6 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (2.2.0)
# Requirement already satisfied: opencv-python-headless in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (3.4.18.65)
# Requirement already satisfied: fastremap in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (1.14.1)
# Requirement already satisfied: imagecodecs in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (2024.1.1)
# Requirement already satisfied: roifile in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from cellpose) (2024.1.10)
# Requirement already satisfied: filelock in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (4.9.0)
# Requirement already satisfied: sympy in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (1.12)
# Requirement already satisfied: networkx in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (3.1)
# Requirement already satisfied: jinja2 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (3.1.3)
# Requirement already satisfied: fsspec in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.19.3 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (2.19.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (12.1.105)
# Requirement already satisfied: triton==2.2.0 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from torch>=1.6->cellpose) (2.2.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->cellpose) (12.3.101)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from jinja2->torch>=1.6->cellpose) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages (from sympy->torch>=1.6->cellpose) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Check CUDA version and that GPU is working in cellpose and import other libraries.

# %%
# !nvcc --version
# !nvidia-smi

import os, shutil
import numpy as np
import matplotlib.pyplot as plt
from cellpose import core, utils, io, models, metrics
from glob import glob

use_GPU = core.use_gpu()
yn = ['NO', 'YES']
print(f'>>> GPU activated? {yn[use_GPU]}')
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Fri_Jan__6_16:45:21_PST_2023
# Cuda compilation tools, release 12.0, V12.0.140
# Build cuda_12.0.r12.0/compiler.32267302_0
# Thu Jun 20 21:57:54 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.171.04             Driver Version: 535.171.04   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 4090        Off | 00000000:01:00.0  On |                  Off |
# |  0%   60C    P5              40W / 450W |   1392MiB / 24564MiB |     34%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      2430      G   /usr/lib/xorg/Xorg                          544MiB |
# |    0   N/A  N/A      3069      G   /usr/bin/gnome-shell                        103MiB |
# |    0   N/A  N/A      3828      G   /opt/teamviewer/tv_bin/TeamViewer             6MiB |
# |    0   N/A  N/A      5529      G   ./steamwebhelper                              8MiB |
# |    0   N/A  N/A      6583      G   ...76,262144 --variations-seed-version      202MiB |
# |    0   N/A  N/A      6584      G   ...37,262144 --variations-seed-version       39MiB |
# |    0   N/A  N/A     22152      G   ...erProcess --variations-seed-version      243MiB |
# |    0   N/A  N/A     24509      G   ...wardCache --variations-seed-version       38MiB |
# |    0   N/A  N/A     40106      G   /usr/bin/nautilus                            32MiB |
# |    0   N/A  N/A     54991      G   /usr/bin/gnome-control-center                14MiB |
# +---------------------------------------------------------------------------------------+
# >>> GPU activated? YES

# %% [markdown]
# ### Download sample images (optional)
#
# If you don't mount your google drive, and want to test cellpose 2.0, run the next code block to download the example data. This `human_in_the_loop` folder has a `train` folder with training images and manual segmentations (in this case created in the loop), and a `test` folder with test images and manual segmentations from scratch.
#
# These images are from the breast vectra class from the Tissuenet dataset. The full Tissuenet dataset is available [here](https://datasets.deepcell.org/), and for a description of the data see the [paper](https://www.nature.com/articles/s41587-021-01094-0).
#
# We will convert the `_seg.npy` files to `_masks.tif` files.

# %%
from natsort import natsorted

# %%
from natsort import natsorted
#url = 'https://drive.google.com/uc?id=1HXpLczf7TPCdI1yZY5KV3EkdWzRrgvhQ'
#utils.download_url_to_file(url, 'human_in_the_loop.zip')

#!unzip human_in_the_loop
train_files = natsorted(glob('augmented/train/*.tif'))
train_seg = natsorted(glob('augmented/train/*.npy'))

test_files = natsorted(glob('augmented/test/*.npy'))
test_seg = natsorted(glob('augmented/test/*.npy'))

# %% [markdown]
# what the training images look like + their labels

# %%
plt.figure(figsize=(12,4), dpi=300)
for k,f in enumerate(train_files):
    img = io.imread(f)
    plt.subplot(2,len(train_files),k+1)
    img = np.vstack((img, np.zeros_like(img)[:1]))
    img = img.transpose(1,2,0)
    plt.imshow(img)
    plt.axis('off')

    plt.subplot(2,len(train_files),len(train_files) + k+1)
    seg = np.load(os.path.splitext(f)[0] + '_seg.npy', allow_pickle=True).item()
    masks= seg['masks'].squeeze()
    plt.imshow(masks)
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/numpy/lib/npyio.py:465, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     464 try:
# --> 465     return pickle.load(fid, **pickle_kwargs)
#     466 except Exception as e:
#
# UnpicklingError: pickle data was truncated
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[15], line 11
#       8 plt.axis('off')
#      10 plt.subplot(2,len(train_files),len(train_files) + k+1)
# ---> 11 seg = np.load(os.path.splitext(f)[0] + '_seg.npy', allow_pickle=True).item()
#      12 masks= seg['masks'].squeeze()
#      13 plt.imshow(masks)
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/numpy/lib/npyio.py:467, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     465     return pickle.load(fid, **pickle_kwargs)
#     466 except Exception as e:
# --> 467     raise pickle.UnpicklingError(
#     468         f"Failed to interpret file {file!r} as a pickle") from e
#
# UnpicklingError: Failed to interpret file 'augmented/train/left_mirrored_img_0_seg.npy' as a pickle

# %%
plt.figure(figsize=(12,4), dpi=300)
for k,f in enumerate(train_files):
    img = io.imread(f)
    plt.subplot(2,len(train_files),k+1)
    img = np.vstack((img, np.zeros_like(img)[:1]))
    img = img.transpose(1,2,0)
    plt.imshow(img)
    plt.axis('off')

    plt.subplot(2,len(train_files),len(train_files) + k+1)
    seg = np.load(os.path.splitext(f)[0] + '_seg.npy', allow_pickle=True).item()
    masks= seg['masks'].squeeze()
    plt.imshow(masks)
    plt.axis('off')
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/numpy/lib/npyio.py:465, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     464 try:
# --> 465     return pickle.load(fid, **pickle_kwargs)
#     466 except Exception as e:
#
# UnpicklingError: pickle data was truncated
#
# The above exception was the direct cause of the following exception:
#
# UnpicklingError                           Traceback (most recent call last)
# Cell In[16], line 11
#       8 plt.axis('off')
#      10 plt.subplot(2,len(train_files),len(train_files) + k+1)
# ---> 11 seg = np.load(os.path.splitext(f)[0] + '_seg.npy', allow_pickle=True).item()
#      12 masks= seg['masks'].squeeze()
#      13 plt.imshow(masks)
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/numpy/lib/npyio.py:467, in load(file, mmap_mode, allow_pickle, fix_imports, encoding, max_header_size)
#     465     return pickle.load(fid, **pickle_kwargs)
#     466 except Exception as e:
# --> 467     raise pickle.UnpicklingError(
#     468         f"Failed to interpret file {file!r} as a pickle") from e
#
# UnpicklingError: Failed to interpret file 'augmented/train/left_mirrored_img_0_seg.npy' as a pickle

# %% [markdown]
# # Train model on manual annotations
#
# Skip this step if you already have a pretrained model.
#
# Fill out the form below with the paths to your data and the parameters to start training.

# %% [markdown]
# ## Training parameters
#
# <font size = 4> **Paths for training, predictions and results**
#
#
# <font size = 4>**`train_dir:`, `test_dir`:** These are the paths to your folders train_dir (with images and masks of training images) and test_dir (with images and masks of test images). You can leave the test_dir blank, but it's recommended to have some test images to check the model's performance. To find the paths of the folders containing the respective datasets, go to your Files on the left of the notebook, navigate to the folder containing your files and copy the path by right-clicking on the folder, **Copy path** and pasting it into the right box below.
#
# <font size = 4>**`initial_model`:** Choose a model from the cellpose [model zoo](https://cellpose.readthedocs.io/en/latest/models.html#model-zoo) to start from.
#
# <font size = 4>**`model_name`**: Enter the path where your model will be saved once trained (for instance your result folder).
#
# <font size = 4>**Training parameters**
#
# <font size = 4>**`number_of_epochs`:** Input how many epochs (rounds) the network will be trained. At least 100 epochs are recommended, but sometimes 250 epochs are necessary, particularly from scratch. **Default value: 100**

# %%
TRAIN_PATH = "archive/fold_0/train"
TEST_PATH = "archive/fold_0/val"

WIDTH = 704
HEIGHT = 520

# %%
from cellpose import io, models, train
io.logger_setup()

output = io.load_train_test_data(train_dir=TRAIN_PATH, test_dir=TEST_PATH, image_filter='_img', mask_filter='_masks', 
                                 look_one_level_down=False)
images, labels, image_names, test_images, test_labels, image_names_test = output
test_model = models.CellposeModel(model_type="cyto3")
model_path = train.train_seg(model.net, train_data=images, train_labels=labels,
                            channels=[1,2], normalize=True,
                            test_data=test_images, test_labels=test_labels,
                            weight_decay=1e-4, SGD=True, learning_rate=0.1,
                            n_epochs=100, model_name="my_new_model")
# Out:
# 2024-06-15 21:34:47,672 [INFO] WRITING LOG OUTPUT TO /home/sam/.cellpose/run.log
# 2024-06-15 21:34:47,673 [INFO]
# cellpose version: 	3.0.7
# platform:       	linux
# python version: 	3.10.13
# torch version:  	2.2.0+cu121
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_276874/1499005495.py in ?()
#       1 from cellpose import io, models, train
#       2 io.logger_setup()
#       3
# ----> 4 output = io.load_train_test_data(train_dir=TRAIN_PATH, test_dir=TEST_PATH, image_filter='_img', mask_filter='_masks',
#       5                                  look_one_level_down=False)
#       6 images, labels, image_names, test_images, test_labels, image_names_test = output
#       7 test_model = models.CellposeModel(model_type="cyto3")
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/cellpose/io.py in ?(train_dir, test_dir, image_filter, mask_filter, look_one_level_down)
#     457         test_images (list, optional): A list of testing images. None if test_dir is not provided.
#     458         test_labels (list, optional): A list of labels corresponding to the testing images. None if test_dir is not provided.
#     459         test_image_names (list, optional): A list of names of the testing images. None if test_dir is not provided.
#     460     """
# --> 461     images, labels, image_names = load_images_labels(train_dir, mask_filter,
#     462                                                      image_filter, look_one_level_down)
#     463
#     464     # testing data
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/cellpose/io.py in ?(tdir, mask_filter, image_filter, look_one_level_down)
#     424     for n in range(nimg):
#     425         if os.path.isfile(label_names[n]) or os.path.isfile(flow_names[0]):
#     426             image = imread(image_names[n])
#     427             if label_names is not None:
# --> 428                 label = imread(label_names[n])
#     429             if flow_names is not None:
#     430                 flow = imread(flow_names[n])
#     431                 if flow.shape[0] < 4:
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/cellpose/io.py in ?(filename)
#     167                     full_shape = tif.series[0].shape
#     168                 except:
#     169                     ltif = 0
#     170             if ltif < 10:
# --> 171                 img = tif.asarray()
#     172             else:
#     173                 page = tif.series[0][0]
#     174                 shape, dtype = page.shape, page.dtype
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, key, series, level, squeeze, out, maxworkers, buffersize)
#    4486         elif len(pages) == 1:
#    4487             page0 = pages[0]
#    4488             if page0 is None:
#    4489                 raise ValueError('page is None')
# -> 4490             result = page0.asarray(
#    4491                 out=out, maxworkers=maxworkers, buffersize=buffersize
#    4492             )
#    4493         else:
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, out, squeeze, lock, maxworkers, buffersize)
#    9282                     ]
#    9283                 # except IndexError:
#    9284                 #     pass  # corrupted file, for example, with too many strips
#    9285
# -> 9286             for _ in self.segments(
#    9287                 func=func,
#    9288                 lock=lock,
#    9289                 maxworkers=maxworkers,
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/tifffile/tifffile.py in ?(self, lock, maxworkers, func, sort, buffersize, _fullsize)
#    9078                 sort=sort,
#    9079                 buffersize=buffersize,
#    9080                 flat=True,
#    9081             ):
# -> 9082                 yield decode(segment)
#    9083         else:
#    9084             # reduce memory overhead by processing chunks of up to
#    9085             # buffersize of segments because ThreadPoolExecutor.map is not
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/tifffile/tifffile.py in ?(args, decodeargs, decode)
#    9068             def decode(args, decodeargs=decodeargs, decode=keyframe.decode):
# -> 9069                 return func(decode(*args, **decodeargs))  # type: ignore
#
# ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/tifffile/tifffile.py in ?(data, index, jpegtables, jpegheader, _fullsize)
#    8990                 data = imagecodecs.bitorder_decode(data)
#    8991             if decompress is not None:
#    8992                 # TODO: calculate correct size for packed integers
#    8993                 size = shape[0] * shape[1] * shape[2] * shape[3]
# -> 8994                 data = decompress(data, out=size * dtype.itemsize)
#    8995             data_array = unpack(data)  # type: ignore
#    8996             # del data
#    8997             data_array = reshape(data_array, segmentindex, shape)
#
# KeyboardInterrupt:

# %%
train_dir = "archive/fold_0/train" 
test_dir = "archive/fold_0/val" 
#Define where the patch file will be saved
base = "/content"

# model name and path
from cellpose import models
initial_model = "cyto3" #["cyto", "cyto3","nuclei","tissuenet_cp3", "livecell_cp3", "yeast_PhC_cp3", "yeast_BF_cp3", "bact_phase_cp3", "bact_fluor_cp3", "deepbacs_cp3", "scratch"]
model_name = "CP_tissuenet" 

# other parameters for training.
n_epochs = 100

Channel_to_use_for_training = "Grayscale" # ["Grayscale", "Blue", "Green", "Red"]

# If you have a secondary channel that can be used for training, for instance nuclei, choose it here:

Second_training_channel= "None" #@param ["None", "Blue", "Green", "Red"]


# Advanced Parameters

Use_Default_Advanced_Parameters = True 
##If not, please input:
learning_rate = 0.1 
weight_decay = 0.0001

if (Use_Default_Advanced_Parameters): 
  print("Default advanced parameters enabled")
  learning_rate = 0.1 
  weight_decay = 0.0001
  
#here we check that no model with the same name already exist, if so delete
model_path = train_dir + 'models/'
if os.path.exists(model_path+'/'+model_name):
  print("!! WARNING: "+model_name+" already exists and will be deleted in the following cell !!")
  
if len(test_dir) == 0:
  test_dir = None

# Here we match the channel to number
if Channel_to_use_for_training == "Grayscale":
  chan = 0
elif Channel_to_use_for_training == "Blue":
  chan = 3
elif Channel_to_use_for_training == "Green":
  chan = 2
elif Channel_to_use_for_training == "Red":
  chan = 1


if Second_training_channel == "Blue":
  chan2 = 3
elif Second_training_channel == "Green":
  chan2 = 2
elif Second_training_channel == "Red":
  chan2 = 1
elif Second_training_channel == "None":
  chan2 = 0

if initial_model=='scratch':
  initial_model = 'None'
# Out:
# Default advanced parameters enabled

# %% [markdown]
# ## Train new model
#
# Using settings from form above, train model in notebook.

# %%
train_labels[0].shape
# Out:
# (520, 520, 3)

# %%
train_data[0].shape
# Out:
# (520, 520, 3)

# %%
from cellpose import train 

# start logger (to see training across epochs)
logger = io.logger_setup()

# DEFINE CELLPOSE MODEL (without size model)
model = models.CellposeModel(gpu=use_GPU, model_type=initial_model)

# set channels
channels = [0, 0]

# get files
output = io.load_train_test_data(train_dir=TRAIN_PATH, test_dir=TEST_PATH, image_filter='_img', mask_filter='_masks', 
                                 look_one_level_down=False)
#output = io.load_train_test_data(train_dir, test_dir, mask_filter='_masks.tif')
train_data, train_labels, _, test_data, test_labels, _ = output

new_model_path = train.train_seg(model.net, train_data=train_data, 
                              train_labels=train_labels, 
                              test_data=test_data,
                              test_labels=test_labels,
                              channels=channels, 
                              save_path=train_dir, 
                              n_epochs=n_epochs,
                              learning_rate=learning_rate, 
                              weight_decay=weight_decay, 
                              SGD=True,
                              nimg_per_epoch=8,
                              model_name=model_name)

# diameter of labels in training images
diam_labels = model.net.diam_labels.item()
# Out:
# 2024-06-15 22:19:00,133 [INFO] WRITING LOG OUTPUT TO /home/sam/.cellpose/run.log
# 2024-06-15 22:19:00,133 [INFO]
# cellpose version: 	3.0.7
# platform:       	linux
# python version: 	3.10.13
# torch version:  	2.2.0+cu121
# 2024-06-15 22:19:00,133 [INFO] >> cyto3 << model set to be used
# 2024-06-15 22:19:00,150 [INFO] ** TORCH CUDA version installed and working. **
# 2024-06-15 22:19:00,150 [INFO] >>>> using GPU
# 2024-06-15 22:19:00,220 [INFO] >>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# 2024-06-15 22:19:05,439 [INFO] 485 / 485 images in archive/fold_0/train folder have labels
# 2024-06-15 22:19:05,895 [INFO] 121 / 121 images in archive/fold_0/val folder have labels
# 2024-06-15 22:19:05,910 [INFO] flows precomputed
# 2024-06-15 22:19:06,401 [INFO] flows precomputed
# 2024-06-15 22:19:06,585 [INFO] >>> computing diameters
# 100%|██████████| 485/485 [00:00<00:00, 33408.95it/s]
# 100%|██████████| 121/121 [00:00<00:00, 2153.20it/s]
# 2024-06-15 22:19:06,659 [INFO] >>> using channels [0, 0]
# 2024-06-15 22:19:06,659 [INFO] >>> normalizing {'lowhigh': None, 'percentile': None, 'normalize': True, 'norm3D': False, 'sharpen_radius': 0, 'smooth_radius': 0, 'tile_norm_blocksize': 0, 'tile_norm_smooth3D': 1, 'invert': False}
# 2024-06-15 22:19:12,337 [INFO] >>> n_epochs=100, n_train=485, n_test=121
# 2024-06-15 22:19:12,337 [INFO] >>> SGD, learning_rate=0.10000, weight_decay=0.00010, momentum=0.900
# 2024-06-15 22:19:12,360 [INFO] >>> saving model to archive/fold_0/train/models/CP_tissuenet
# /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages/torch/nn/modules/loss.py:535: UserWarning: Using a target size (torch.Size([8, 518, 224, 224])) that is different to the input size (torch.Size([8, 2, 224, 224])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[22], line 18
#      15 #output = io.load_train_test_data(train_dir, test_dir, mask_filter='_masks.tif')
#      16 train_data, train_labels, _, test_data, test_labels, _ = output
# ---> 18 new_model_path = train.train_seg(model.net, train_data=train_data,
#      19                               train_labels=train_labels,
#      20                               test_data=test_data,
#      21                               test_labels=test_labels,
#      22                               channels=channels,
#      23                               save_path=train_dir,
#      24                               n_epochs=n_epochs,
#      25                               learning_rate=learning_rate,
#      26                               weight_decay=weight_decay,
#      27                               SGD=True,
#      28                               nimg_per_epoch=8,
#      29                               model_name=model_name)
#      31 # diameter of labels in training images
#      32 diam_labels = model.net.diam_labels.item()
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/cellpose/train.py:431, in train_seg(net, train_data, train_labels, train_files, train_labels_files, train_probs, test_data, test_labels, test_files, test_labels_files, test_probs, load_files, batch_size, learning_rate, n_epochs, weight_decay, momentum, SGD, channels, channel_axis, normalize, compute_flows, save_path, save_every, nimg_per_epoch, nimg_test_per_epoch, rescale, min_train_masks, model_name)
#     429 X = torch.from_numpy(imgi).to(device)
#     430 y = net(X)[0]
# --> 431 loss = _loss_fn_seg(lbl, y, device)
#     432 optimizer.zero_grad()
#     433 loss.backward()
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/cellpose/train.py:33, in _loss_fn_seg(lbl, y, device)
#      31 criterion2 = nn.BCEWithLogitsLoss(reduction="mean")
#      32 veci = 5. * torch.from_numpy(lbl[:, 1:]).to(device)
# ---> 33 loss = criterion(y[:, :2], veci)
#      34 loss /= 2.
#      35 loss2 = criterion2(y[:, -1], torch.from_numpy(lbl[:, 0] > 0.5).to(device).float())
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/torch/nn/modules/loss.py:535, in MSELoss.forward(self, input, target)
#     534 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 535     return F.mse_loss(input, target, reduction=self.reduction)
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/torch/nn/functional.py:3338, in mse_loss(input, target, size_average, reduce, reduction)
#    3335 if size_average is not None or reduce is not None:
#    3336     reduction = _Reduction.legacy_get_string(size_average, reduce)
# -> 3338 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
#    3339 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# File ~/miniconda3/envs/vTerra/lib/python3.10/site-packages/torch/functional.py:76, in broadcast_tensors(*tensors)
#      74 if has_torch_function(tensors):
#      75     return handle_torch_function(broadcast_tensors, tensors, *tensors)
# ---> 76 return _VF.broadcast_tensors(tensors)
#
# RuntimeError: The size of tensor a (2) must match the size of tensor b (518) at non-singleton dimension 1

# %% [markdown]
# ## Evaluate on test data (optional)
#
# If you have test data, check performance

# %%
# get files (during training, test_data is transformed so we will load it again)
output = io.load_train_test_data(test_dir, mask_filter='_seg.npy')
test_data, test_labels = output[:2]

# run model on test images
masks = model.eval(test_data, 
                   channels=[chan, chan2],
                   diameter=diam_labels)[0]

# check performance using ground truth labels
ap = metrics.average_precision(test_labels, masks)[0]
print('')
print(f'>>> average precision at iou threshold 0.5 = {ap[:,0].mean():.3f}')
# Out:
# 2024-04-30 15:48:59,222 [INFO] not all flows are present, running flow generation for all images
# 2024-04-30 15:48:59,227 [INFO] 3 / 3 images in human_in_the_loop/test folder have labels
# 2024-04-30 15:48:59,228 [INFO] 0%|          | 0/3 [00:00<?, ?it/s]
# 2024-04-30 15:48:59,468 [INFO] 100%|##########| 3/3 [00:00<00:00, 12.53it/s]
#
# >>> average precision at iou threshold 0.5 = 0.729

# %% [markdown]
# plot masks

# %%
plt.figure(figsize=(12,8), dpi=150)
for k,im in enumerate(test_data):
    img = im.copy()
    plt.subplot(3,len(train_files), k+1)
    img = np.vstack((img, np.zeros_like(img)[:1]))
    img = img.transpose(1,2,0)
    plt.imshow(img)
    plt.axis('off')
    if k==0:
        plt.title('image')

    plt.subplot(3,len(train_files), len(train_files) + k+1)
    plt.imshow(masks[k])
    plt.axis('off')
    if k==0:
        plt.title('predicted labels')

    plt.subplot(3,len(train_files), 2*len(train_files) + k+1)
    plt.imshow(test_labels[k])
    plt.axis('off')
    if k==0:
        plt.title('true labels')
plt.tight_layout()

# %% [markdown]
# # Use custom model to segment images
#
# Take custom trained model from above, or upload your own model to google drive / colab runtime.
#
# ## Parameters

# %%
# model name and path

#@markdown ###Custom model path (full path):

model_path = "human_in_the_loop/train/models/CP_tissuenet" #@param {type:"string"}

#@markdown ###Path to images:

dir = "human_in_the_loop/test" #@param {type:"string"}

#@markdown ###Channel Parameters:

Channel_to_use_for_segmentation = "Green" #@param ["Grayscale", "Blue", "Green", "Red"]

# @markdown If you have a secondary channel that can be used, for instance nuclei, choose it here:

Second_segmentation_channel= "Red" #@param ["None", "Blue", "Green", "Red"]


# Here we match the channel to number
if Channel_to_use_for_segmentation == "Grayscale":
  chan = 0
elif Channel_to_use_for_segmentation == "Blue":
  chan = 3
elif Channel_to_use_for_segmentation == "Green":
  chan = 2
elif Channel_to_use_for_segmentation == "Red":
  chan = 1


if Second_segmentation_channel == "Blue":
  chan2 = 3
elif Second_segmentation_channel == "Green":
  chan2 = 2
elif Second_segmentation_channel == "Red":
  chan2 = 1
elif Second_segmentation_channel == "None":
  chan2 = 0

#@markdown ### Segmentation parameters:

#@markdown diameter of cells (set to zero to use diameter from training set):
diameter =  0#@param {type:"number"}
#@markdown threshold on flow error to accept a mask (set higher to get more cells, e.g. in range from (0.1, 3.0), OR set to 0.0 to turn off so no cells discarded):
flow_threshold = 0.4 #@param {type:"slider", min:0.0, max:3.0, step:0.1}
#@markdown threshold on cellprob output to seed cell masks (set lower to include more pixels or higher to include fewer, e.g. in range from (-6, 6)):
cellprob_threshold=0 #@param {type:"slider", min:-6, max:6, step:1}

# %% [markdown]
# if you're using the example test data we'll copy it to a new folder

# %%
src = 'human_in_the_loop/test'
if dir[:len(src)] == src:
    files = io.get_image_files(dir, '_masks')
    dir = 'human_in_the_loop/eval/'
    os.makedirs(dir, exist_ok=True)
    for f in files:
        dst = dir + os.path.split(f)[1]
        print(f'{f} > {dst}')
        shutil.copyfile(f, dst)
# Out:
# human_in_the_loop/test/breast_vectra_0.tif > human_in_the_loop/eval/breast_vectra_0.tif
# human_in_the_loop/test/img_1213.tif > human_in_the_loop/eval/img_1213.tif
# human_in_the_loop/test/img_1220.tif > human_in_the_loop/eval/img_1220.tif

# %% [markdown]
# ## run custom model
#
# how to run the custom model in a notebook

# %%
# gets image files in dir (ignoring image files ending in _masks)
files = io.get_image_files(dir, '_masks')
print(files)
images = [io.imread(f) for f in files]

# declare model
model = models.CellposeModel(gpu=True, 
                             pretrained_model=model_path)

# use model diameter if user diameter is 0
diameter = model.diam_labels if diameter==0 else diameter

# run model on test images
masks, flows, styles = model.eval(images, 
                                  channels=[chan, chan2],
                                  diameter=diameter,
                                  flow_threshold=flow_threshold,
                                  cellprob_threshold=cellprob_threshold
                                  )
# Out:
# ['human_in_the_loop/eval/breast_vectra_0.tif', 'human_in_the_loop/eval/breast_vectra_0_outlines.png', 'human_in_the_loop/eval/img_1213.tif', 'human_in_the_loop/eval/img_1213_outlines.png', 'human_in_the_loop/eval/img_1220.tif', 'human_in_the_loop/eval/img_1220_outlines.png']
# 2024-04-30 15:49:26,959 [INFO] >>>> loading model human_in_the_loop/train/models/CP_tissuenet
# 2024-04-30 15:49:26,979 [INFO] ** TORCH CUDA version installed and working. **
# 2024-04-30 15:49:26,980 [INFO] >>>> using GPU
# 2024-04-30 15:49:27,046 [INFO] >>>> model diam_mean =  30.000 (ROIs rescaled to this size during training)
# 2024-04-30 15:49:27,047 [INFO] >>>> model diam_labels =  19.259 (mean diameter of training ROIs)
# 2024-04-30 15:49:27,048 [INFO] 0%|          | 0/6 [00:00<?, ?it/s]
# 2024-04-30 15:49:27,439 [INFO] 100%|##########| 6/6 [00:00<00:00, 15.35it/s]

# %% [markdown]
# ## save output to *_seg.npy
#
# you will see the files save in the Files tab and you can download them from there

# %%
from cellpose import io

io.masks_flows_to_seg(images, 
                      masks, 
                      flows, 
                      files, 
                      channels=[chan, chan2],
                      diams=diameter*np.ones(len(masks)), 
                      )

# %% [markdown]
# ## save output masks to tiffs/pngs or txt files for imageJ

# %%
import inspect
from cellpose.io import save_masks
file_location = inspect.getfile(save_masks)
print("File Location:", file_location)
# Out:
# File Location: /home/sam/miniconda3/envs/vTerra/lib/python3.10/site-packages/cellpose/io.py

# %%
io.save_masks(images, 
              masks, 
              flows, 
              files, 
              channels=[chan, chan2],
              png=True, # save masks as PNGs and save example image
              tif=True, # save masks as TIFFs
              save_txt=True, # save txt outlines for ImageJ
              save_flows=False, # save flows as TIFFs
              save_outlines=True, # save outlines as TIFFs 
              save_mpl=True # make matplotlib fig to view (WARNING: SLOW W/ LARGE IMAGES)
              )

# %%
num_masks = len(np.unique(masks)) - 1  # Subtract 1 to exclude the background label (0)

print(f"Number of masks: {num_masks}")
# Out:
# Number of masks: 178

# %%
outline_arr = []
for i in range(178):
    arg = (masks[0], i)
    out = utils.get_outline_multi(arg)
    outline_arr.append(out)

# %%
args = (masks[0], 1)
outline_1 = utils.get_outline_multi(args)

# %%
outline_arr[0]

# %%
import numpy as np

# Assuming image is your original image and outline_arr is your list of outlines
image = np.zeros((256, 256))  # Replace height and width with the actual dimensions of your image

for i, outline in enumerate(outline_arr):
    for point in outline:
        x, y = point  # Assuming point is a tuple (x, y)
        image[x, y] = i + 1  # Assign the label (i+1) to the corresponding position in the image

# %%
import matplotlib.pyplot as plt

# Assuming 'image' is your 2D numpy array
# Create a color map
cmap = plt.cm.get_cmap('cividis')

# Plot the image with the colormap
plt.imshow(image, cmap=cmap)
plt.colorbar()
plt.show()
# Out:
# /tmp/ipykernel_209939/524635034.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   cmap = plt.cm.get_cmap('cividis')

# %%
nr_objects

# %%
import matplotlib.pyplot as plt
from scipy.ndimage import label

# Assuming 'outlines' is your 2D numpy array
labeled, nr_objects = label(outlines)

# Create a color map
cmap = plt.cm.get_cmap('nipy_spectral', nr_objects)

# Plot the labeled outlines
plt.imshow(labeled, cmap=cmap)
plt.colorbar()
plt.show()

# %%
plt.imshow(outline_arr)
plt.axis('off')  # Optional: Turn off the axis labels
plt.show()

# %%
import numpy as np

# Convert masks to numpy array
masks_array = masks[0]

# Generate outlines from masks
outlines = utils.masks_to_outlines(masks_array)

# %%
import numpy as np
# Assuming "outlines" is a numpy array
np.set_printoptions(threshold=np.inf)
print(outlines)

# %%
import matplotlib.pyplot as plt

# Assuming you have an RGB image stored in the variable 'img'
plt.imshow(outlines)
plt.axis('off')  # Optional: Turn off the axis labels
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming masks is a list of numpy arrays
for mask in masks:
    plt.imshow(mask, cmap='gray')
    plt.show()

# %%
files[0]

# %%
f = files[0]
plt.figure(figsize=(12,4), dpi=300)
plt.imshow(io.imread(os.path.splitext(f)[0] + '_cp_output.png'))
plt.axis('off')
